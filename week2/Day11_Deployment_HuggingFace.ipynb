# %%
# !pip install ultralytics gradio huggingface_hub -q

from ultralytics import YOLO
import gradio as gr
print("✅ Setup Complete!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.8 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Setup Complete!

# %% [markdown]
# # Day 11: Model Deployment to Hugging Face Spaces
#
# **Objectives:**
# - Optimize model for faster inference
# - Create Production-ready Gradio App
# - Deploy to Hugging Face (free public link)
# - Make portfolio-ready project

# %%
# Load your best model


def detect_objects(image, confidence=0.25):
    results = model.predict(image, conf=confidence, verbose=False)
    annotated = results[0].plot()
    return annotated

# Beautiful Gradio Interface
with gr.Blocks(title="Smart Waste / Vehicle Detector") as demo:
    gr.Markdown("# 🚀 Smart Object Detection System")
    gr.Markdown("### Powered by YOLO11 | Deployed on Hugging Face")

    with gr.Row():
        with gr.Column():
            input_image = gr.Image(type="pil", label="Upload Image")
            conf_slider = gr.Slider(0.1, 0.9, value=0.25, step=0.05, label="Confidence Threshold")
            btn = gr.Button("Detect Objects", variant="primary")

        with gr.Column():
            output_image = gr.Image(label="Detection Result")

    btn.click(
        fn=detect_objects,
        inputs=[input_image, conf_slider],
        outputs=output_image
    )

demo.launch(share=True)
